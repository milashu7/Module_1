# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

### добиться автоматической загрузки файла без мануального режима
from google.colab import files
uploaded = files.upload()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#      <input type="file" id="files-53e0db8e-c0a0-4d28-b828-838f1827266b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53e0db8e-c0a0-4d28-b828-838f1827266b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving movie_bd_v5.csv to movie_bd_v5.csv

# %%
data = pd.read_csv("movie_bd_v5.csv")
data.sample(5)

# %%
data.describe()
# Out:
#              budget       revenue  ...  release_year        profit
# count  1.889000e+03  1.889000e+03  ...   1889.000000  1.889000e+03
# mean   5.431083e+07  1.553653e+08  ...   2007.860773  1.010545e+08
# std    4.858721e+07  2.146698e+08  ...      4.468841  1.830733e+08
# min    5.000000e+06  2.033165e+06  ...   2000.000000 -1.657101e+08
# 25%    2.000000e+07  3.456058e+07  ...   2004.000000  5.000000e+06
# 50%    3.800000e+07  8.361541e+07  ...   2008.000000  4.400041e+07
# 75%    7.200000e+07  1.782626e+08  ...   2012.000000  1.201842e+08
# max    3.800000e+08  2.781506e+09  ...   2015.000000  2.544506e+09
#
# [8 rows x 6 columns]

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов

# тут другие ваши предобработки колонок например:
data['profit'] = data['revenue'] - data['budget']

# the time given in the dataset is in string format.
# So we need to change this in datetime format
# ...

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
answers['1'] = '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)' # +

# %%
# тут пишем ваш код для решения данного вопроса:
display (data[data.budget==data.budget.max()].original_title)
# Out:
# 723    Pirates of the Caribbean: On Stranger Tides
# Name: original_title, dtype: object

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
answers['2'] = '2. Gods and Generals (tt0279111)'

# %%
display (data[data.runtime==data.runtime.max()].original_title)
# Out:
# 1157    Gods and Generals
# Name: original_title, dtype: object

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = '3. Winnie the Pooh (tt1449283)'

# %%
display (data[data.runtime==data.runtime.min()].original_title)
# Out:
# 768    Winnie the Pooh
# Name: original_title, dtype: object

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '2. 110'

# %%
display(data.runtime.mean())
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '1. 107'

# %%
display(data.runtime.median())
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
answers['6'] = '5. Avatar (tt0499549)'

# %%
# лучше код получения столбца profit вынести в Предобработку что в начале
# data['profit']=data['revenue']-data['budget']

display(data[['imdb_id','original_title', 'profit']].sort_values(['profit'], ascending=False))

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
answers['7'] = '5. The Lone Ranger (tt1210819)'

# %%
display(data[['imdb_id','original_title', 'profit']].sort_values(['profit']))
# Out:
#         imdb_id                original_title      profit
# 1245  tt1210819               The Lone Ranger  -165710090
# 1616  tt0318974                     The Alamo  -119180039
# 809   tt1305591               Mars Needs Moms  -111007242
# 958   tt0180052  The Adventures of Pluto Nash   -92896027
# 1464  tt0424095                  Flushed Away   -84540684
# ...         ...                           ...         ...
# 970   tt0848228                  The Avengers  1299557910
# 4     tt2820852                     Furious 7  1316249360
# 0     tt0369610                Jurassic World  1363528810
# 3     tt2488496  Star Wars: The Force Awakens  1868178225
# 239   tt0499549                        Avatar  2544505847
#
# [1889 rows x 3 columns]

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
answers['8'] = '1. 1478'

# %%
display (len(data[data.profit>0]))
# Out:
# 1478

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
answers['9'] = '4. The Dark Knight (tt0468569)'

# %%
data_9 = data[data.release_year==2008]
# display(data_9.sort_values(['profit'],ascending=False))
display(data_9[['imdb_id','original_title', 'profit']].sort_values(['profit'],ascending=False))

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
answers['10'] = '5. The Lone Ranger (tt1210819)'

# %%
data_10 = data[(data.release_year>=2012)&(data.release_year<=2014)]
display(data_10[['imdb_id','original_title', 'profit','release_year']].sort_values(['profit']))
# Out:
#         imdb_id                   original_title      profit  release_year
# 1245  tt1210819                  The Lone Ranger  -165710090          2013
# 1214  tt0790736                         R.I.P.D.   -68351500          2013
# 1007  tt1374992                      Upside Down   -51893525          2012
# 1302  tt0884726  Legends of Oz: Dorothy's Return   -51337973          2013
# 1235  tt1308729               Bullet to the Head   -45510171          2013
# ...         ...                              ...         ...           ...
# 1189  tt1690953                  Despicable Me 2   894761885          2013
# 974   tt1074638                          Skyfall   908561013          2012
# 1180  tt1300854                       Iron Man 3  1015439994          2013
# 1177  tt2294629                           Frozen  1124219009          2013
# 970   tt0848228                     The Avengers  1299557910          2012
#
# [367 rows x 4 columns]

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
answers['11'] = '3. Drama' # +

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале

# %% [markdown]
# ВАРИАНТ 2

# %%
display(pd.Series(data['genres'].str.cat(sep='|').split('|')).value_counts())
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# dtype: int64

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
answers['12'] = '1. Drama' # +

# %%
data12 = data[data['profit']<0]
# display (data12)
# display (pd.Series(data12['genres'].str.cat(sep='|').split('|')))
display(pd.Series(data12['genres'].str.cat(sep='|').split('|')).value_counts())

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сбооры?

# %%
answers['13'] = '5. Peter Jackson' # +

# %%
data_13 = data[['director', 'revenue']]
data_13.director = data_13.director.apply(lambda s: s.split('|'))
data_13_exploded = data_13.explode('director')
display(data_13_exploded.groupby(by = 'director').revenue.sum().sort_values(ascending = False))
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# director
# Peter Jackson        6490593685
# Christopher Nolan    4167548502
# David Yates          4154295625
# Michael Bay          3886938960
# J.J. Abrams          3579169916
#                         ...
# David MichÃ´d           2295423
# Steven Shainberg        2281089
# Paul Schrader           2062066
# Keanu Reeves            2054941
# Simon Hunter            2033165
# Name: revenue, Length: 997, dtype: int64

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
answers['14'] = '3. Robert Rodriguez' # +

# %%
data_14 = data[data['genres'].str.contains('Action')] 
display(pd.Series(data_14['director'].str.cat(sep='|').split('|')).value_counts())
# Out:
# Robert Rodriguez      9
# Paul W.S. Anderson    7
# Michael Bay           7
# Antoine Fuqua         6
# Ridley Scott          6
#                      ..
# Chris Miller          1
# Rob Letterman         1
# Tommy Wirkola         1
# Mike McCoy            1
# Terry Gilliam         1
# Length: 364, dtype: int64

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
answers['15'] = '3. Chris Hemsworth' # +

# %%
data_15 = data[data.release_year == 2012][['cast', 'revenue']]
data_15.cast = data_15.cast.apply(lambda s: s.split('|'))
data_15_exploded = data_15.explode('cast')
data_15_exploded.groupby(by = 'cast').revenue.sum().sort_values(ascending = False)
# Out:
# cast
# Chris Hemsworth      2027450773
# Denis Leary          1629460639
# Anne Hathaway        1522851057
# Chris Evans          1519557910
# Robert Downey Jr.    1519557910
#                         ...
# Jason Bateman           3428048
# Danny Huston            2106557
# Sami Gayle              2106557
# Josh Lucas              2106557
# Nicolas Cage            2106557
# Name: revenue, Length: 466, dtype: int64

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
answers['16'] = '3. Matt Damon'  # +

# %%
data_16 = data[data.budget > data.budget.mean()]
display(pd.Series(data_16['cast'].str.cat(sep='|').split('|')).value_counts())
# Out:
# Matt Damon           18
# Adam Sandler         17
# Angelina Jolie       16
# Samuel L. Jackson    15
# Tom Cruise           15
#                      ..
# Jennifer Saunders     1
# Eugenio Derbez        1
# Shawn Driscoll        1
# Mo Zinal              1
# Seth MacFarlane       1
# Length: 1505, dtype: int64

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
answers['17'] = '2. Action' # +

# %%
data_17 = data[data['cast'].str.contains('Nicolas Cage')] 
display(pd.Series(data_17['genres'].str.cat(sep='|').split('|')).value_counts())
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Family              3
# Mystery             3
# Animation           3
# History             2
# War                 1
# Romance             1
# Horror              1
# dtype: int64

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
answers['18'] = '1. K-19: The Widowmaker (tt0267626)' # +

# %%
data_18 = data[data['production_companies'].str.contains('Paramount Pictures')] 
display(data_18[['imdb_id','original_title', 'profit']].sort_values(['profit']))
# Out:
#         imdb_id                                     original_title     profit
# 925   tt0267626                               K-19: The Widowmaker  -64831034
# 1123  tt0300556                                           Timeline  -60519261
# 1722  tt0435705                                               Next  -51788987
# 1623  tt0375173                                              Alfie  -46604061
# 1631  tt0315297                                            Twisted  -24805000
# ...         ...                                                ...        ...
# 730   tt1229238               Mission: Impossible - Ghost Protocol  549713380
# 1738  tt0418279                                       Transformers  559709780
# 603   tt0367882  Indiana Jones and the Kingdom of the Crystal S...  601636033
# 317   tt1055369                Transformers: Revenge of the Fallen  686297228
# 828   tt1399103                     Transformers: Dark of the Moon  928746996
#
# [122 rows x 3 columns]

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
answers['19'] = '5. 2015' # +

# %%
data_19 = data.groupby(['release_year'])['revenue'].sum().sort_values(ascending=False) 
display(data_19)

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
answers['20'] = '1. 2014' # +

# %%
data_20 = data[data['production_companies'].str.contains('Warner Bros')] 
display(data_20.groupby(['release_year'])['revenue'].sum().sort_values(ascending=False))
# Out:
# release_year
# 2014    3243064519
# 2007    3183675217
# 2008    3050595031
# 2010    3008712985
# 2011    2845393682
# 2003    2745493377
# 2009    2737954136
# 2004    2731933725
# 2013    2599953400
# 2005    2412980298
# 2001    2266545668
# 2012    1869520056
# 2002    1702709901
# 2015    1691168351
# 2006    1521170743
# 2000    1025531386
# Name: revenue, dtype: int64

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
answers['21'] = '4. Сентябрь' # +

# %%
def month_in_date(s): 
  #s = '160/9/2015'
  s = str(s)
  m = s[:s.find('/')]
  return m # int(m)

data['release_month'] = data.release_date.apply(month_in_date)
display(data['release_month'].value_counts(ascending=False))
# Out:
# 9     227
# 12    190
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: release_month, dtype: int64

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
answers['22'] = '2. 450' # +

# %%
data_22=data[(data['release_month']=='6') |(data['release_month']=='7')|(data['release_month']=='8')]
display(len(data_22))
# Out:
# 450

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
answers['23'] = '5. Peter Jackson' # +

# %%
data_23=data[(data['release_month']=='12') |(data['release_month']=='1')|(data['release_month']=='2')]
data_23.director = data_23.director.apply(lambda s: s.split('|'))
data_23_exploded = data_23.explode('director')
display(data_23_exploded['director'].value_counts(ascending = False))
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# Peter Jackson          7
# Steven Soderbergh      6
# Clint Eastwood         6
# Shawn Levy             4
# Martin Scorsese        4
#                       ..
# Jonas Elmer            1
# Jason Moore            1
# Scott Stewart          1
# Demian Lichtenstein    1
# Mark Pellington        1
# Name: director, Length: 358, dtype: int64

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
answers['24'] = '5. Four By Two Productions' # +

# %%
data ['lenght'] = data.original_title.map(lambda x: len(x))
data_24 = data.copy()
data_24.production_companies = data_24.production_companies.apply(lambda s: s.split('|'))
data_24_exploded = data_24.explode('production_companies')
display(data_24_exploded.groupby(['production_companies'])['lenght'].max().sort_values(ascending=False))
# Out:
# production_companies
# Four By Two Productions                   83
# Twentieth Century Fox Film Corporation    83
# Walden Media                              62
# Walt Disney                               62
# Jim Henson Company, The                   59
#                                           ..
# Everest Entertainment                      3
# Berlanti Productions                       3
# XM2 Productions                            2
# Global Entertainment Group                 2
# Ixtlan Productions                         2
# Name: lenght, Length: 1771, dtype: int64

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
answers['25'] = '3. Midnight Picture Show' # +

# %%
data ['len_over'] = data.overview.map(lambda x: len(x))
data_25 = data.copy()
data_25.production_companies = data_25.production_companies.apply(lambda s: s.split('|'))
data_25_exploded = data_25.explode('production_companies')
display(data_25_exploded.groupby(['production_companies'])['len_over'].mean().sort_values(ascending=False))
# Out:
# production_companies
# Midnight Picture Show                    1000.0
# Room 9 Entertainment                      964.0
# Brookwell-McNamara Entertainment          936.0
# Lions Gate Family Entertainment           909.0
# Crest Animation Productions               909.0
#                                           ...
# Projection Pictures                        74.0
# London Boulevard                           74.0
# Phantom Four                               72.0
# Empire Pictures                            62.0
# Motion Picture Corporation of America      59.0
# Name: len_over, Length: 1771, dtype: float64

# %%
# display(data[data['production_companies'].str.contains('Midnig')])

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?
# по vote_average

# %%
answers['26'] = '1. Inside Out, The Dark Knight, 12 Years a Slave' # +

# %%
data_best = data[data['vote_average'] > data.quantile(0.99, numeric_only=True)['vote_average']]
display(data_best[['imdb_id','original_title', 'vote_average']].sort_values(['vote_average'],ascending=False))
# Out:
#         imdb_id                                 original_title  vote_average
# 599   tt0468569                                The Dark Knight           8.1
# 9     tt2096673                                     Inside Out           8.0
# 34    tt3170832                                           Room           8.0
# 118   tt0816692                                   Interstellar           8.0
# 125   tt2084970                             The Imitation Game           8.0
# 119   tt2015381                        Guardians of the Galaxy           7.9
# 128   tt2267998                                      Gone Girl           7.9
# 138   tt2278388                       The Grand Budapest Hotel           7.9
# 370   tt1375666                                      Inception           7.9
# 872   tt0253474                                    The Pianist           7.9
# 1081  tt0167260  The Lord of the Rings: The Return of the King           7.9
# ...

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %%
answers['27'] = '5. Daniel Radcliffe & Rupert Grint' # +

# %% [markdown]
# ВАРИАНТ 2

# %%
from itertools import combinations
actor_list = data.cast.str.split('|').tolist()
combo_list=[]
for i in actor_list:
    for j in combinations(i, 2):
        combo_list.append(' '.join(sorted(j)))
combo_list = pd.DataFrame(combo_list)
combo_list.columns = ['actor_combinations']
combo_list.actor_combinations.value_counts().head(20)
# Out:
# Daniel Radcliffe Rupert Grint        8
# Emma Watson Rupert Grint             8
# Daniel Radcliffe Emma Watson         8
# Ben Stiller Owen Wilson              6
# Helena Bonham Carter Johnny Depp     6
# Adam Sandler Kevin James             5
# Paul Walker Vin Diesel               5
# Robert Pattinson Taylor Lautner      5
# Hugh Jackman Ian McKellen            5
# Kristen Stewart Taylor Lautner       5
# Kristen Stewart Robert Pattinson     5
# George Clooney Matt Damon            4
# Costas Mandylor Tobin Bell           4
# Jennifer Lawrence Josh Hutcherson    4
# Chris Evans Scarlett Johansson       4
# Josh Hutcherson Woody Harrelson      4
# Betsy Russell Tobin Bell             4
# Cameron Diaz Mike Myers              4
# Peter Facinelli Taylor Lautner       4
# Paul Rudd Steve Carell               4
# Name: actor_combinations, dtype: int64

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
display(answers)
# Out:
# {'1': '5. Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '10': '5. The Lone Ranger (tt1210819)',
#  '11': '3. Drama',
#  '12': '1. Drama',
#  '13': '5. Peter Jackson',
#  '14': '3. Robert Rodriguez',
#  '15': '3. Chris Hemsworth',
#  '16': '3. Matt Damon',
#  '17': '2. Action',
#  '18': '1. K-19: The Widowmaker (tt0267626)',
#  '19': '5. 2015',
#  '2': '2. Gods and Generals (tt0279111)',
#  '20': '1. 2014',
#  '21': '4. Сентябрь',
#  '22': '2. 450',
#  '23': '5. Peter Jackson',
#  '24': '5. Four By Two Productions',
#  '25': '3. Midnight Picture Show',
#  '26': '1. Inside Out, The Dark Knight, 12 Years a Slave',
#  '27': '5. Daniel Radcliffe & Rupert Grint',
#  '3': '3. Winnie the Pooh (tt1449283)',
#  '4': '2. 110',
#  '5': '1. 107',
#  '6': '5. Avatar (tt0499549)',
#  '7': '5. The Lone Ranger (tt1210819)',
#  '8': '1. 1478',
#  '9': '4. The Dark Knight (tt0468569)'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 16
